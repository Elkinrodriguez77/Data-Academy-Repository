# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("www.datos.gov.co", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(www.datos.gov.co,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("upr9-nkiz", limit=30000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("www.datos.gov.co", None)

all_results = []
limit = 2000
offset = 0

while True:
    results = client.get("upr9-nkiz", limit=limit, offset=offset)
    if not results:
        break
    all_results.extend(results)
    offset += limit

results_df = pd.DataFrame.from_records(all_results)
#print(f"Total registros cargados: {len(results_df)}")
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Total registros cargados: 27005

# %%
results_df.head()
# Out:
#   codigoinstitucion                 nombreinstitucion codigodepartinstitucion  \
# 0              1101  UNIVERSIDAD NACIONAL DE COLOMBIA                      11
# 1              1101  UNIVERSIDAD NACIONAL DE COLOMBIA                      11
# 2              1101  UNIVERSIDAD NACIONAL DE COLOMBIA                      11
# 3              1101  UNIVERSIDAD NACIONAL DE COLOMBIA                      11
# 4              1101  UNIVERSIDAD NACIONAL DE COLOMBIA                      11
#
#   nombredepartinstitucion codigomunicipioinstitucion  \
# 0             Bogotá D.C.                      11001
# 1             Bogotá D.C.                      11001
# 2             Bogotá D.C.                      11001
# 3             Bogotá D.C.                      11001
# 4             Bogotá D.C.                      11001
#
#   nombremunicipioinstitucion codigoorigeninstitucional  \
# 0                Bogotá D.C.                         1
# 1                Bogotá D.C.                         1
# 2                Bogotá D.C.                         1
# 3                Bogotá D.C.                         1
# 4                Bogotá D.C.                         1
#
#   nombreorigeninstitucional codigocaracteracademico nombrecaracteracademico  \
# 0                   Oficial                       4             Universidad
# 1                   Oficial                       4             Universidad
# 2                   Oficial                       4             Universidad
# 3                   Oficial                       4             Universidad
# 4                   Oficial                       4             Universidad
#
#    ... nombrenivelacademico codigoperiodicidad nombreperiodicidad  \
# 0  ...             Pregrado                  2          Semestral
# 1  ...             Pregrado                  2          Semestral
# 2  ...             Pregrado                  2          Semestral
# 3  ...             Pregrado                  2          Semestral
# 4  ...             Pregrado                  2          Semestral
#
#   cantidadperiodos numeroresolucionacreditacion codigotipoacreditacion  \
# 0               10                        19584                      3
# 1                9                        19587                      3
# 2               10                        11945                      3
# 3               10                        12325                      3
# 4               10                        16035                      3
#
#          nombretipoacreditacion aniosacreditados  \
# 0  Acreditación de alta calidad                6
# 1  Acreditación de alta calidad                8
# 2  Acreditación de alta calidad                6
# 3  Acreditación de alta calidad                6
# 4  Acreditación de alta calidad               85
#
#            nombretituloobtenido fechacreacion
# 0  ADMINISTRADOR(A) DE EMPRESAS    27/09/2017
# 1                ANTROPOLOGO(A)    27/09/2017
# 2                 ARQUITECTO(A)    16/06/2016
# 3    MAESTRO EN ARTES PLASTICAS    28/09/2012
# 4                    BIOLOGO(A)    10/12/2012
#
# [5 rows x 39 columns]

# %%
results_df.shape
# Out:
# (27005, 39)
